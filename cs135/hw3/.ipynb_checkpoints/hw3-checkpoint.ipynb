# %% [markdown]
# # HW3 : Logistic Regression and Neural Networks
#
# ### Instructions
#
# The authoritative HW3 instructions are on the course website:
#
# http://www.cs.tufts.edu/cs/135/2025s/hw3.html
#
# Please report any questions to Piazza.
#
# ### Outline of this Notebook

# %%
import os
import numpy as np
import pandas as pd
import time
import warnings

# %%
# import plotting libraries
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.0, style='whitegrid')

# %% [markdown]
# Allow autoreload of student-edited code to be reflected in this notebook

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import LRGradientDescent 

insert_final_col_of_all_ones = LRGradientDescent.insert_final_col_of_all_ones
LogisticRegressionGradientDescent = LRGradientDescent.LogisticRegressionGradientDescent

# %% [markdown]
# # Create toy dataset with F=1 input dimension
#
# Each input $x_n$ is one position on number line
#
# Each label $y_n$ is binary, either 0 or 1

# %%
# Toy problem 
# Logistic regression should be able to perfectly predict all 10 examples
N = 10
xoffset = 1.23
x_NF = xoffset + np.hstack([
    np.linspace(-2, -1, 5), np.linspace(1, 2, 5)])[:,np.newaxis]
y_N = np.hstack([np.zeros(5), np.ones(5)])

# %%
plt.plot(x_NF[:,0], y_N, 'ks');
plt.xlabel('x');
plt.ylabel('y');

# %% [markdown]
# ## Setup

# %%
fixedb = -1.0 # Fix bias coef at -1 for now, we'll learn it later in 1B

xone_NG = insert_final_col_of_all_ones(x_NF)

# %% [markdown]
# ## Debugging Figure: Show phat as function of x for different w
#
# You don't need this for your report, but this is for your *understanding* to make sure your predict_proba is correct
#
# No need to edit here. Read thru to understand this code and what it's doing.
# Then use it to help debug your `predict_proba` implementation

# %%
w_candidates_A = [-1., 1, 3, 7]

A = len(w_candidates_A)
fig, axgrid = plt.subplots(nrows=1, ncols=A, figsize=(4*A+1,3), sharex=True, sharey=True)

L = 101
xdense_L = np.linspace(-2, 4, L)
xdense_L1 = xdense_L[:,np.newaxis]

tmplr = LogisticRegressionGradientDescent(C=1000.0)

for aa in range(len(w_candidates_A)):
    curw = w_candidates_A[aa]
    
    # Hard-code the values of wtil_G so they reflect current w value
    tmplr.wtil_G = np.asarray([curw, fixedb]);
    
    # Evaluate phat with current wtil_G, across L different dense x values
    phat_L = tmplr.predict_proba(xdense_L1)[:,1]

    # Show predicted phat probability alongside true labels
    axgrid[aa].plot(xdense_L, phat_L, 'm-');
    axgrid[aa].plot(x_NF[:,0], y_N, 'k.', markersize=8);
    
    # Make pretty title to help with debugging
    curJ = tmplr.calc_loss(tmplr.wtil_G, xone_NG, y_N)
    panel = axgrid[aa]
    panel.set_title('  w  =% .1f  b=%.1f\nJ(w) = %.3f ' % (curw, fixedb, curJ),
                         x=0.0,
                         font='monospace', fontsize=14,
                         horizontalalignment='left')
    panel.set_xticks([-2, 0, 2, 4]);
    panel.set_xlabel(r'$x_n$')
    if aa == 0:
        panel.set_ylabel(r'$p(y_n=1 | x_n)$');

# %% [markdown]
# ## Step 1A: Evaluate loss and grad across dense grid of w values
#
# This prepares for Fig 1a

# %%
fixedb = -1.0 # Fix bias coef

# %%
xone_NG = insert_final_col_of_all_ones(x_NF)
G = xone_NG.shape[1]

# %%
mylr = LogisticRegressionGradientDescent(C=10.0)

# %%
## Perform numerical search over a fine grid of w values
H = 201 # num grid points
w_grid_H = np.linspace(-2, 11, H)
loss_grid_H = np.zeros_like(w_grid_H)
grad_grid_H = np.zeros_like(w_grid_H)

for hh in range(H):
    wtil_G = np.asarray([w_grid_H[hh], fixedb])
    loss = tmplr.calc_loss(wtil_G, xone_NG, y_N)
    grad_G = tmplr.calc_grad(wtil_G, xone_NG, y_N)
    loss_grid_H[hh] = loss
    grad_grid_H[hh] = grad_G[0]

# %% [markdown]
# ## Figure 1a: Loss and Grad vs w
#
# If your calc_loss and calc_grad implementations are correct, you shouldn't need to edit anything in this block
#
# This block helps visualize loss J and its grad as a function of w

# %%
fig, axgrid = plt.subplots(nrows=1, ncols=2, figsize=(7,3), sharex=True, sharey=False)

loss_panel = axgrid[0]
loss_panel.plot(w_grid_H, loss_grid_H, 'b-');
loss_panel.set_ylim([0.0, 5.0]);
loss_panel.set_xticks([-2, 0, 2, 4, 6, 8, 10]);
loss_panel.set_xlabel('w')
loss_panel.set_ylabel('loss J')

grad_panel = axgrid[1]
grad_panel.plot(w_grid_H, grad_grid_H, 'b-');
grad_panel.set_ylim([-2, 1]);
grad_panel.set_yticks([-2, -1, 0, 1]);
grad_panel.set_xlabel('w')
grad_panel.set_ylabel('grad of J wrt w')

plt.suptitle("Fig 1a: loss and grad when C = %.3g" % mylr.C, fontsize=12);

plt.tight_layout();

# %% [markdown]
# ## Caption of Fig 1a: Part 1

# %% [markdown]
# Write in report. See instructions.

# %% [markdown]
# ## Caption of Fig 1a: Part 2

# %% [markdown]
# TODO find the values in w_grid_H that correspond to lowest loss value in loss_grid_H
#
# Make sure the answer here gets moved to your report

# %%
min_i = np.argmin(loss_grid_H)

if min_i > 0 and min_i < len(w_grid_H) - 1:
    lower_bound = w_grid_H[min_i - 1]
    upper_bound = w_grid_H[min_i + 1]
else:
    lower_bound = w_grid_H[min_i] - 0.01
    upper_bound = w_grid_H[min_i] + 0.01

print("Lowest value is between %.3f and %.3f" % (lower_bound, upper_bound))
# Out:
# Lowest value is between 3.200 and 3.330

# %% [markdown]
# ## Step 1B

# %% [markdown]
# Using this toy data, `init_w_recipe='zeros'` and call `fit` with an appropriate step size to run gradient descent. Be sure to verify convergence. If it doesn't converge, adjust your step size accordingly.

# %%
step_size = 2.5

mylr_fromzeros = LogisticRegressionGradientDescent(
    C=50.0, step_size=step_size, num_iterations=1000, init_recipe='zeros')

mylr_fromzeros.fit(x_NF, y_N)
# Out:
# Initializing G=2 parameters in wtil_G via recipe: zeros
# Running GD for up to 1000 iters with step_size 2.5
# iter   0/1000  loss   1.000000  avg_abs_grad   0.541011  w   0.000 b   0.000
# iter   1/1000  loss   0.361175  avg_abs_grad   0.135224  w   2.705 b   0.000
# iter   2/1000  loss   0.225513  avg_abs_grad   0.088819  w   2.745 b  -0.637
# iter   3/1000  loss   0.160926  avg_abs_grad   0.064564  w   2.756 b  -1.069
# iter   4/1000  loss   0.125075  avg_abs_grad   0.050365  w   2.761 b  -1.387
# iter   5/1000  loss   0.102938  avg_abs_grad   0.041308  w   2.766 b  -1.634
# iter   6/1000  loss   0.088204  avg_abs_grad   0.035145  w   2.772 b  -1.835
# iter   7/1000  loss   0.077839  avg_abs_grad   0.030734  w   2.780 b  -2.002
# iter   8/1000  loss   0.070225  avg_abs_grad   0.027442  w   2.791 b  -2.144
# iter   9/1000  loss   0.064432  avg_abs_grad   0.024894  w   2.805 b  -2.268
# iter  10/1000  loss   0.059890  avg_abs_grad   0.022858  w   2.821 b  -2.376
# iter  11/1000  loss   0.056238  avg_abs_grad   0.021185  w   2.839 b  -2.472
# iter  12/1000  loss   0.053236  avg_abs_grad   0.019777  w   2.859 b  -2.559
# iter  13/1000  loss   0.050720  avg_abs_grad   0.018566  w   2.879 b  -2.637
# iter  14/1000  loss   0.048577  avg_abs_grad   0.017507  w   2.901 b  -2.709
# iter  15/1000  loss   0.046726  avg_abs_grad   0.016568  w   2.923 b  -2.774
# iter  16/1000  loss   0.045108  avg_abs_grad   0.015727  w   2.945 b  -2.835
# iter  17/1000  loss   0.043680  avg_abs_grad   0.014965  w   2.967 b  -2.891
# iter  18/1000  loss   0.042408  avg_abs_grad   0.014271  w   2.989 b  -2.944
# iter  19/1000  loss   0.041268  avg_abs_grad   0.013634  w   3.011 b  -2.994
# iter  20/1000  loss   0.040239  avg_abs_grad   0.013047  w   3.033 b  -3.040
# iter  21/1000  loss   0.039306  avg_abs_grad   0.012505  w   3.054 b  -3.084
# iter  40/1000  loss   0.030397  avg_abs_grad   0.006675  w   3.368 b  -3.647
# iter  41/1000  loss   0.030162  avg_abs_grad   0.006499  w   3.380 b  -3.668
# iter  60/1000  loss   0.027317  avg_abs_grad   0.004206  w   3.564 b  -3.986
# iter  61/1000  loss   0.027223  avg_abs_grad   0.004122  w   3.572 b  -3.999
# iter  80/1000  loss   0.025962  avg_abs_grad   0.002925  w   3.691 b  -4.213
# iter  81/1000  loss   0.025916  avg_abs_grad   0.002877  w   3.696 b  -4.222
# iter 100/1000  loss   0.025263  avg_abs_grad   0.002153  w   3.779 b  -4.378
# iter 101/1000  loss   0.025238  avg_abs_grad   0.002123  w   3.782 b  -4.385
# iter 120/1000  loss   0.024867  avg_abs_grad   0.001645  w   3.843 b  -4.503
# iter 121/1000  loss   0.024853  avg_abs_grad   0.001624  w   3.846 b  -4.508
# iter 140/1000  loss   0.024630  avg_abs_grad   0.001288  w   3.892 b  -4.600
# iter 141/1000  loss   0.024620  avg_abs_grad   0.001273  w   3.895 b  -4.604
# iter 160/1000  loss   0.024480  avg_abs_grad   0.001027  w   3.931 b  -4.678
# iter 161/1000  loss   0.024474  avg_abs_grad   0.001016  w   3.933 b  -4.681
# iter 180/1000  loss   0.024384  avg_abs_grad   0.000831  w   3.961 b  -4.740
# iter 181/1000  loss   0.024380  avg_abs_grad   0.000822  w   3.963 b  -4.743
# iter 200/1000  loss   0.024320  avg_abs_grad   0.000679  w   3.986 b  -4.791
# iter 201/1000  loss   0.024317  avg_abs_grad   0.000672  w   3.987 b  -4.793
# iter 220/1000  loss   0.024277  avg_abs_grad   0.000559  w   4.006 b  -4.833
# iter 221/1000  loss   0.024275  avg_abs_grad   0.000554  w   4.007 b  -4.835
# iter 240/1000  loss   0.024247  avg_abs_grad   0.000463  w   4.022 b  -4.868
# iter 241/1000  loss   0.024246  avg_abs_grad   0.000459  w   4.023 b  -4.869
# iter 260/1000  loss   0.024227  avg_abs_grad   0.000386  w   4.036 b  -4.897
# iter 261/1000  loss   0.024226  avg_abs_grad   0.000382  w   4.037 b  -4.898
# iter 280/1000  loss   0.024213  avg_abs_grad   0.000323  w   4.047 b  -4.921
# iter 281/1000  loss   0.024212  avg_abs_grad   0.000320  w   4.048 b  -4.922
# iter 300/1000  loss   0.024203  avg_abs_grad   0.000271  w   4.057 b  -4.941
# iter 301/1000  loss   0.024202  avg_abs_grad   0.000269  w   4.057 b  -4.942
# iter 320/1000  loss   0.024196  avg_abs_grad   0.000228  w   4.065 b  -4.958
# iter 321/1000  loss   0.024195  avg_abs_grad   0.000226  w   4.065 b  -4.959
# iter 340/1000  loss   0.024191  avg_abs_grad   0.000193  w   4.071 b  -4.973
# iter 341/1000  loss   0.024190  avg_abs_grad   0.000191  w   4.072 b  -4.973
# iter 360/1000  loss   0.024187  avg_abs_grad   0.000163  w   4.077 b  -4.985
# iter 361/1000  loss   0.024187  avg_abs_grad   0.000162  w   4.077 b  -4.985
# iter 380/1000  loss   0.024184  avg_abs_grad   0.000138  w   4.082 b  -4.995
# iter 381/1000  loss   0.024184  avg_abs_grad   0.000137  w   4.082 b  -4.995
# iter 400/1000  loss   0.024183  avg_abs_grad   0.000117  w   4.086 b  -5.004
# iter 401/1000  loss   0.024183  avg_abs_grad   0.000116  w   4.086 b  -5.004
# iter 420/1000  loss   0.024181  avg_abs_grad   0.000099  w   4.089 b  -5.011
# iter 421/1000  loss   0.024181  avg_abs_grad   0.000099  w   4.089 b  -5.011
# iter 440/1000  loss   0.024180  avg_abs_grad   0.000084  w   4.092 b  -5.017
# iter 441/1000  loss   0.024180  avg_abs_grad   0.000084  w   4.092 b  -5.018
# iter 460/1000  loss   0.024180  avg_abs_grad   0.000072  w   4.095 b  -5.023
# iter 461/1000  loss   0.024180  avg_abs_grad   0.000071  w   4.095 b  -5.023
# iter 480/1000  loss   0.024179  avg_abs_grad   0.000061  w   4.097 b  -5.027
# iter 481/1000  loss   0.024179  avg_abs_grad   0.000061  w   4.097 b  -5.028
# iter 500/1000  loss   0.024179  avg_abs_grad   0.000052  w   4.098 b  -5.031
# iter 501/1000  loss   0.024179  avg_abs_grad   0.000052  w   4.099 b  -5.031
# iter 520/1000  loss   0.024179  avg_abs_grad   0.000044  w   4.100 b  -5.035
# iter 521/1000  loss   0.024179  avg_abs_grad   0.000044  w   4.100 b  -5.035
# iter 540/1000  loss   0.024178  avg_abs_grad   0.000038  w   4.101 b  -5.037
# iter 541/1000  loss   0.024178  avg_abs_grad   0.000038  w   4.101 b  -5.038
# iter 560/1000  loss   0.024178  avg_abs_grad   0.000032  w   4.102 b  -5.040
# iter 561/1000  loss   0.024178  avg_abs_grad   0.000032  w   4.102 b  -5.040
# iter 580/1000  loss   0.024178  avg_abs_grad   0.000028  w   4.103 b  -5.042
# iter 581/1000  loss   0.024178  avg_abs_grad   0.000027  w   4.103 b  -5.042
# iter 600/1000  loss   0.024178  avg_abs_grad   0.000023  w   4.104 b  -5.044
# iter 601/1000  loss   0.024178  avg_abs_grad   0.000023  w   4.104 b  -5.044
# iter 620/1000  loss   0.024178  avg_abs_grad   0.000020  w   4.105 b  -5.045
# iter 621/1000  loss   0.024178  avg_abs_grad   0.000020  w   4.105 b  -5.045
# iter 640/1000  loss   0.024178  avg_abs_grad   0.000017  w   4.105 b  -5.046
# iter 641/1000  loss   0.024178  avg_abs_grad   0.000017  w   4.105 b  -5.046
# iter 660/1000  loss   0.024178  avg_abs_grad   0.000015  w   4.106 b  -5.047
# iter 661/1000  loss   0.024178  avg_abs_grad   0.000014  w   4.106 b  -5.047
# iter 680/1000  loss   0.024178  avg_abs_grad   0.000012  w   4.106 b  -5.048
# iter 681/1000  loss   0.024178  avg_abs_grad   0.000012  w   4.106 b  -5.048
# iter 700/1000  loss   0.024178  avg_abs_grad   0.000011  w   4.107 b  -5.049
# iter 701/1000  loss   0.024178  avg_abs_grad   0.000011  w   4.107 b  -5.049
# iter 720/1000  loss   0.024178  avg_abs_grad   0.000009  w   4.107 b  -5.050
# iter 721/1000  loss   0.024178  avg_abs_grad   0.000009  w   4.107 b  -5.050
# iter 740/1000  loss   0.024178  avg_abs_grad   0.000008  w   4.107 b  -5.050
# iter 741/1000  loss   0.024178  avg_abs_grad   0.000008  w   4.107 b  -5.050
# iter 760/1000  loss   0.024178  avg_abs_grad   0.000007  w   4.107 b  -5.051
# iter 761/1000  loss   0.024178  avg_abs_grad   0.000007  w   4.107 b  -5.051
# iter 780/1000  loss   0.024178  avg_abs_grad   0.000006  w   4.108 b  -5.051
# iter 781/1000  loss   0.024178  avg_abs_grad   0.000006  w   4.108 b  -5.051
# iter 800/1000  loss   0.024178  avg_abs_grad   0.000005  w   4.108 b  -5.052
# iter 801/1000  loss   0.024178  avg_abs_grad   0.000005  w   4.108 b  -5.052
# iter 820/1000  loss   0.024178  avg_abs_grad   0.000004  w   4.108 b  -5.052
# iter 821/1000  loss   0.024178  avg_abs_grad   0.000004  w   4.108 b  -5.052
# iter 840/1000  loss   0.024178  avg_abs_grad   0.000004  w   4.108 b  -5.052
# iter 841/1000  loss   0.024178  avg_abs_grad   0.000004  w   4.108 b  -5.052
# iter 860/1000  loss   0.024178  avg_abs_grad   0.000003  w   4.108 b  -5.052
# iter 861/1000  loss   0.024178  avg_abs_grad   0.000003  w   4.108 b  -5.053
# iter 880/1000  loss   0.024178  avg_abs_grad   0.000003  w   4.108 b  -5.053
# iter 881/1000  loss   0.024178  avg_abs_grad   0.000003  w   4.108 b  -5.053
# iter 900/1000  loss   0.024178  avg_abs_grad   0.000002  w   4.108 b  -5.053
# iter 901/1000  loss   0.024178  avg_abs_grad   0.000002  w   4.108 b  -5.053
# Done. Converged after 917 iters with step_size 2.5

# %% [markdown]
# ## Step 1B part two: trace plotting
#
# Edit the function below to make sure you are plotting the history of your gradient descent run.
#
# Only lines marked TODO need to be edited.
#
# Please don't mess with the styling or ylims if at all possible.
# If you find yourself messing with those, it may indicate a bug.

# %%
def make_trace_plots(mylr, figsize=(11,3),
                    loss_ylims=[-0.01, 0.2],
                    grad_ylims=[-0.01, 0.2],
                    param_ylims=[-10, 12],
                    xtick_every=100):
    fig, axgrid = plt.subplots(nrows=1, ncols=3, figsize=figsize, sharex=True, sharey=False)
    loss_panel = axgrid[0]
    grad_panel = axgrid[1]
    param_panel = axgrid[2]
    
    try:
        xmax = max(mylr.trace_steps)
    except:
        xmax = 100
    
    loss_panel.plot(mylr.trace_steps, mylr.trace_loss, 'm')
    loss_panel.set_ylim(loss_ylims)
    loss_panel.set_xlabel('iter')
    loss_panel.set_ylabel('loss J')
    loss_panel.set_xticks(np.arange(0, xmax, xtick_every))
    
    grad_panel.plot(mylr.trace_steps, mylr.trace_grad_L1_norm, 'm')
    grad_panel.set_ylim(grad_ylims)
    grad_panel.set_xlabel('iter')
    grad_panel.set_ylabel('sum(abs(grad_G))')
    
    step_list = mylr.trace_steps
    w_list = [wtil_G[0] for wtil_G in mylr.trace_param] if mylr.trace_param else [0]
    b_list = [wtil_G[-1] for wtil_G in mylr.trace_param] if mylr.trace_param else [0]

    param_panel.plot(step_list, w_list, 'b', label='w')
    param_panel.plot(step_list, b_list, 'r', label='b')    
    param_panel.legend(loc='upper right')
    param_panel.set_xlabel('iter')
    param_panel.set_ylim(param_ylims)
    param_panel.set_ylabel('param. val.')
    
    plt.tight_layout()

# %% [markdown]
# ## Figure 1b: Trace plots for from-zeros run

# %%
make_trace_plots(mylr_fromzeros)

# %% [markdown]
# TODO in your report: **In a brief caption**, indicate the `step_size` used and why you picked that value.

# %% [markdown]
# FYI as a bonus exercise for your own understanding, you could try calling fit using a different initialization (random), and compare the trace plots of that call to the ones above.

# %% [markdown]
# ## Step 1C: Verify your implementation matches sklearn

# %% [markdown]
# Setup numpy so we print out arrays nicely to only 3 decimal places

# %%
def pprint_float(fval):
    return '% .3f' % fval

pretty_formatter = {'float': pprint_float}
np.set_printoptions(formatter=pretty_formatter)

# %%
import sklearn.metrics
from sklearn.linear_model import LogisticRegression

row_list = list()

for C in [500.0, 5.0, 0.005]:
    sklr = LogisticRegression(C=C, max_iter=999, solver='lbfgs', random_state=0)
    sklr.fit(x_NF, y_N)
    
    sklr_wtil_G = sklr.coef_.flatten().tolist() + [sklr.intercept_[0]]
    sklr_loss = np.mean(sklr.predict_proba(x_NF)[:, 1] - y_N) ** 2  

    row_dict = {'C': C, 'method': 'sklearn',
                'wtil_G': str(sklr_wtil_G),
                'loss': sklr_loss,
                'solver_status': 'converged' if sklr.n_iter_[0] < 999 else 'not converged'}
    row_list.append(row_dict)

    if C >= 100:
        step_size = 15
    elif C >= 1:
        step_size = 10
    else:
        step_size = 0.05

    mylr = LogisticRegressionGradientDescent(
        C=C, 
        step_size=step_size,
        use_base2_for_BCE=False,
        num_iterations=999,
        verbose=False
    )
    mylr.fit(x_NF, y_N)

    mylr_wtil_G = mylr.wtil_G.tolist() if hasattr(mylr, 'wtil_G') else [0] * G
    mylr_loss = mylr.trace_loss[-1] if mylr.trace_loss else float('inf')

    row_dict = {'C': C, 'method': 'my code',
                'wtil_G': str(mylr_wtil_G),
                'loss': mylr_loss,
                'solver_status': mylr.solver_status}
    row_list.append(row_dict)

    print("C = %9.3f" % C)
    print(mylr.solver_status)
# Out:
# ALERT! Divergence detected. Loss should never be NaN
# Recent history of loss values:
# iter    0  loss    0.693147
# iter    1  loss         nan
# /Users/iabou-jaoude.21/Halligan/cs135/hw3/LRGradientDescent.py:329: RuntimeWarning: divide by zero encountered in log
#   sumBCE_loss = -np.sum(y_N * np.log(yhat_N) + (1 - y_N) * np.log(1 - yhat_N))
# /Users/iabou-jaoude.21/Halligan/cs135/hw3/LRGradientDescent.py:329: RuntimeWarning: invalid value encountered in multiply
#   sumBCE_loss = -np.sum(y_N * np.log(yhat_N) + (1 - y_N) * np.log(1 - yhat_N))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 33
#      24     step_size = 0.05
#      26 mylr = LogisticRegressionGradientDescent(
#      27     C=C,
#      28     step_size=step_size,
#    (...)
#      31     verbose=False
#      32 )
# ---> 33 mylr.fit(x_NF, y_N)
#      35 mylr_wtil_G = mylr.wtil_G.tolist() if hasattr(mylr, 'wtil_G') else [0] * G
#      36 mylr_loss = mylr.trace_loss[-1] if mylr.trace_loss else float('inf')
#
# File ~/Halligan/cs135/hw3/LRGradientDescent.py:272, in LogisticRegressionGradientDescent.fit(self, x_NF, y_N)
#     269 self.trace_param.append(wtil_G)
#     271 # Assess divergence and raise ValueError as soon as it happens
# --> 272 self.raise_error_if_diverging(
#     273     self.trace_steps, self.trace_loss, self.trace_grad_L1_norm)
#     275 # Assess convergence and break early if happens
#     276 self.did_converge = self.check_convergence(
#     277     self.trace_steps, self.trace_loss,
#     278     self.trace_grad_L1_norm, self.trace_param)
#
# File ~/Halligan/cs135/hw3/LRGradientDescent.py:553, in LogisticRegressionGradientDescent.raise_error_if_diverging(self, trace_steps, trace_loss, trace_grad_L1_norm)
#     549     print("iter %4d  loss % 11.6f" % (
#     550         trace_steps[-M+ii], trace_loss[-M+ii]))
#     551 self.solver_status = "Divergence detected. %s. %s." % (
#     552     reason_str, hint_str)
# --> 553 raise ValueError(self.solver_status)
#
# ValueError: Divergence detected. Loss should never be NaN. Try a smaller step_size than current value 1.600e+01.

# %% [markdown]
# ## Table 1c

# %%
# Convert the rows assembed above into a pandas DataFrame
df = pd.DataFrame(row_list)

# %% [markdown]
# Pretty print the pandas data frame as an HTML table.
# You can copy this into your report.

# %%
pd.set_option('display.max_colwidth', 200)
from IPython.core.display import HTML
HTML(df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>C</th>
#       <th>method</th>
#       <th>wtil_G</th>
#       <th>loss</th>
#       <th>solver_status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500.000</td>
#       <td>sklearn</td>
#       <td>[5.556228235899765, -6.832306569492877]</td>
#       <td>3.590497e-12</td>
#       <td>converged</td>
#     </tr>
#     <tr>
#       <td>500.000</td>
#       <td>my code</td>
#       <td>[5.557736476729951, -6.83840683404262]</td>
#       <td>4.113868e-03</td>
#       <td>Done. NOT converged after 999 iters with step_size 15</td>
#     </tr>
#     <tr>
#       <td>5.000</td>
#       <td>sklearn</td>
#       <td>[2.3602091695159095, -2.9032651096817492]</td>
#       <td>5.461187e-11</td>
#       <td>converged</td>
#     </tr>
#     <tr>
#       <td>5.000</td>
#       <td>my code</td>
#       <td>[2.360277359363638, -2.9031411520177652]</td>
#       <td>9.463034e-02</td>
#       <td>Done. Converged after 127 iters with step_size 10</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>sklearn</td>
#       <td>[0.03641937905713561, -0.04481792955138061]</td>
#       <td>3.045915e-11</td>
#       <td>converged</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>my code</td>
#       <td>[0.03641296512102385, -0.04437852753429263]</td>
#       <td>6.794901e-01</td>
#       <td>Done. Converged after 380 iters with step_size 0.05</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If needed, here's a plain text version of the table you could also include in your report.

# %%
print(df.to_string(index=False))
# Out:
#       C  method                                      wtil_G         loss                                         solver_status
# 500.000 sklearn     [5.556228235899765, -6.832306569492877] 3.590497e-12                                             converged
# 500.000 my code      [5.557736476729951, -6.83840683404262] 4.113868e-03 Done. NOT converged after 999 iters with step_size 15
#   5.000 sklearn   [2.3602091695159095, -2.9032651096817492] 5.461187e-11                                             converged
#   5.000 my code    [2.360277359363638, -2.9031411520177652] 9.463034e-02     Done. Converged after 127 iters with step_size 10
#   0.005 sklearn [0.03641937905713561, -0.04481792955138061] 3.045915e-11                                             converged
#   0.005 my code [0.03641296512102385, -0.04437852753429263] 6.794901e-01   Done. Converged after 380 iters with step_size 0.05

# %% [markdown]
# ### Short answer 1d
#
# See instructions on webpage. Write answer in your report
